# %%
import os
from os.path import join
import numpy as np
import cv2
import shutil
import imutils

# %%
def draw_color_mask(img, borders, color=(0, 0, 0)):
    h = img.shape[0]
    w = img.shape[1]

    x_min = int(borders[0] * w / 100)
    x_max = w - int(borders[2] * w / 100)
    y_min = int(borders[1] * h / 100)
    y_max = h - int(borders[3] * h / 100)
    
    img = cv2.rectangle(img, (0, 0), (x_min, h), color, -1)
    img = cv2.rectangle(img, (0, 0), (w, y_min), color, -1)
    img = cv2.rectangle(img, (x_max, 0), (w, h), color, -1)
    img = cv2.rectangle(img, (0, y_max), (w, h), color, -1)

    return img

# %%
def preprocess_image_change_detection(img, gaussian_blur_radius_list=[13, 13], black_mask=(5, 10, 5, 0)):
    gray = img.copy()
    gray = cv2.cvtColor(gray, cv2.COLOR_BGR2GRAY)
    if gaussian_blur_radius_list is not None:
        for radius in gaussian_blur_radius_list:
            gray = cv2.GaussianBlur(gray, (radius, radius), 0)

    gray = draw_color_mask(gray, black_mask)

    return gray

# %%
def compare_frames_change_detection(prev_frame, next_frame, min_contour_area):
    prev_frame = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)
    next_frame = cv2.cvtColor(next_frame, cv2.COLOR_BGR2GRAY)
    frame_delta = cv2.absdiff(prev_frame, next_frame)
    thresh = cv2.threshold(frame_delta, 45, 255, cv2.THRESH_BINARY)[1]

    thresh = cv2.dilate(thresh, None, iterations=2)
    cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL,
                            cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    #     print('cnts: {}, cnts-shape: {}'.format(cnts, len(cnts)))
    score = 0
    res_cnts = []
#     print('shape of tuple: {}'.format(cnts))
    for c in cnts:
        
        if cv2.contourArea(c) < min_contour_area:
            continue

        res_cnts.append(c)
        score += cv2.contourArea(c)

    return score, res_cnts, thresh

# %% [markdown]
# #### Calling compare_frames_change_detection function to detect and remove similar images

# %%
# Base path 
base_path = join(os.getcwd(), 'c23')
# All frames in a list
all_frames = os.listdir(base_path)

# Create directory to move similar images 
similar_imgs_dir = join(os.getcwd(), 'similar_images')
# Remove directory if exists otherwise create
if(os.path.exists(similar_imgs_dir)):
    # Allowing permission to write
    os.chmod(similar_imgs_dir, 0o777) 
    shutil.rmtree(similar_imgs_dir)
else:
    os.mkdir(similar_imgs_dir)
    
# Create list of similar images indexes
similar_indexes = list()

# Iterate over all frames to set path and get previous and next frames then
for (index, frameName) in enumerate(all_frames, start=0):
    
    if (index < len(all_frames) and index - 1 >= 0):
        prev_frame_path = join(base_path, all_frames[index - 1])
        next_frame_path = join(base_path, all_frames[index])
        
        # Reading previous and next frames
        prev_frame = cv2.imread(prev_frame_path)
        next_frame = cv2.imread(next_frame_path)
        
        # Call frame_changes_detection_function to compare frames
        score, _ , _ = compare_frames_change_detection(prev_frame, next_frame, min_contour_area=50)
        
        if score == 0:
            # Copy similar looking images into a duplicate_images directory
            shutil.copy(join(base_path, frameName), similar_imgs_dir)
            # Appending indexes of similar images to a list to remove later
            similar_indexes.append(index)
            
            print('score_difference: {}, index: {}, frameName: {}'.format(score, index, frameName))
            
        else:
            continue

print('--------------------------- REMOVING SIMILAR IMAGES ------------------------------')           
# Remove similar images from directory based on their indexes
for index in similar_indexes:
    os.remove(join(base_path, all_frames[index]))
    print('Removing frame: {} at index: {}'.format(all_frames[index], index))
print('--------------------------- TOTAL SIMILAR IMAGES FOUND ----------------------------')  
print('Total removed similar images were: {}'.format(len(similar_indexes)))
# Out:
# score_difference: 0, index: 26, frameName: c23-1616696584520.png
# score_difference: 0, index: 33, frameName: c23-1616698981729.png
# score_difference: 0, index: 34, frameName: c23-1616699324009.png
# score_difference: 0, index: 35, frameName: c23-1616699666493.png
# score_difference: 0, index: 36, frameName: c23-1616700009093.png
# score_difference: 0, index: 37, frameName: c23-1616700351574.png
# score_difference: 0, index: 38, frameName: c23-1616700693937.png
# score_difference: 0, index: 39, frameName: c23-1616701036262.png
# score_difference: 0, index: 42, frameName: c23-1616702063501.png
# score_difference: 0, index: 43, frameName: c23-1616702405906.png
# score_difference: 0, index: 44, frameName: c23-1616702748470.png
# score_difference: 0, index: 45, frameName: c23-1616703091109.png
# score_difference: 0, index: 46, frameName: c23-1616703433669.png
# score_difference: 0, index: 49, frameName: c23-1616704460947.png
# score_difference: 0, index: 50, frameName: c23-1616704802950.png
# score_difference: 0, index: 51, frameName: c23-1616705145110.png
# score_difference: 0, index: 54, frameName: c23-1616706171160.png
# score_difference: 0, index: 55, frameName: c23-1616706513398.png
# score_difference: 0, index: 56, frameName: c23-1616706855323.png
# score_difference: 0, index: 57, frameName: c23-1616707197447.png
# score_difference: 0, index: 58, frameName: c23-1616707539404.png
# score_difference: 0, index: 61, frameName: c23-1616708565248.png
# score_difference: 0, index: 62, frameName: c23-1616708907288.png
# score_difference: 0, index: 63, frameName: c23-1616709249289.png
# score_difference: 0, index: 64, frameName: c23-1616709591253.png
# score_difference: 0, index: 65, frameName: c23-1616709933374.png
# score_difference: 0, index: 66, frameName: c23-1616710275420.png
# score_difference: 0, index: 67, frameName: c23-1616710617419.png
# score_difference: 0, index: 70, frameName: c23-1616711644423.png
# score_difference: 0, index: 74, frameName: c23-1616713013068.png
# score_difference: 0, index: 75, frameName: c23-1616713354869.png
# score_difference: 0, index: 76, frameName: c23-1616713696872.png
# score_difference: 0, index: 77, frameName: c23-1616714038835.png
# score_difference: 0, index: 78, frameName: c23-1616714380793.png
# score_difference: 0, index: 81, frameName: c23-1616715406478.png
# score_difference: 0, index: 82, frameName: c23-1616715748441.png
# score_difference: 0, index: 83, frameName: c23-1616716090208.png
# score_difference: 0, index: 84, frameName: c23-1616716432163.png
# score_difference: 0, index: 85, frameName: c23-1616716774165.png
# score_difference: 0, index: 88, frameName: c23-1616717799969.png
# score_difference: 0, index: 89, frameName: c23-1616718142215.png
# score_difference: 0, index: 90, frameName: c23-1616718484220.png
# score_difference: 0, index: 92, frameName: c23-1616719168338.png
# score_difference: 0, index: 94, frameName: c23-1616719852540.png
# score_difference: 0, index: 95, frameName: c23-1616720194661.png
# score_difference: 0, index: 96, frameName: c23-1616720536782.png
# score_difference: 0, index: 97, frameName: c23-1616720878862.png
# score_difference: 0, index: 98, frameName: c23-1616721220750.png
# score_difference: 0, index: 99, frameName: c23-1616721562630.png
# score_difference: 0, index: 100, frameName: c23-1616721904590.png
# score_difference: 0, index: 101, frameName: c23-1616722246353.png
# score_difference: 0, index: 102, frameName: c23-1616722588271.png
# score_difference: 0, index: 103, frameName: c23-1616722930192.png
# score_difference: 0, index: 104, frameName: c23-1616723272395.png
# score_difference: 0, index: 105, frameName: c23-1616723614358.png
# score_difference: 0, index: 106, frameName: c23-1616723956442.png
# score_difference: 0, index: 107, frameName: c23-1616724298401.png
# score_difference: 0, index: 108, frameName: c23-1616724640167.png
# score_difference: 0, index: 109, frameName: c23-1616724982163.png
# score_difference: 0, index: 113, frameName: c23-1616726350617.png
# score_difference: 0, index: 114, frameName: c23-1616726692892.png
# score_difference: 0, index: 115, frameName: c23-1616727034897.png
# score_difference: 0, index: 116, frameName: c23-1616727376939.png
# score_difference: 0, index: 117, frameName: c23-1616727718940.png
# score_difference: 0, index: 118, frameName: c23-1616728060897.png
# score_difference: 0, index: 121, frameName: c23-1616729086908.png
# score_difference: 0, index: 122, frameName: c23-1616729428783.png
# score_difference: 0, index: 123, frameName: c23-1616729770785.png
# score_difference: 0, index: 126, frameName: c23-1616730796952.png
# score_difference: 0, index: 130, frameName: c23-1616732164959.png
# score_difference: 0, index: 145, frameName: c23-1616737298425.png
# score_difference: 0, index: 154, frameName: c23-1616740382406.png
# score_difference: 0, index: 280, frameName: c23-1616783557196.png
# score_difference: 0, index: 281, frameName: c23-1616783899443.png
# score_difference: 0, index: 282, frameName: c23-1616784241640.png
# score_difference: 0, index: 283, frameName: c23-1616784583888.png
# score_difference: 0, index: 286, frameName: c23-1616785611207.png
# score_difference: 0, index: 287, frameName: c23-1616785953569.png
# score_difference: 0, index: 288, frameName: c23-1616786295929.png
# score_difference: 0, index: 289, frameName: c23-1616786638297.png
# score_difference: 0, index: 290, frameName: c23-1616786980657.png
# score_difference: 0, index: 294, frameName: c23-1616788350506.png
# score_difference: 0, index: 295, frameName: c23-1616788692826.png
# score_difference: 0, index: 297, frameName: c23-1616789377672.png
# score_difference: 0, index: 298, frameName: c23-1616789720272.png
# score_difference: 0, index: 299, frameName: c23-1616790062790.png
# score_difference: 0, index: 302, frameName: c23-1616791089592.png
# score_difference: 0, index: 303, frameName: c23-1616791431629.png
# score_difference: 0, index: 304, frameName: c23-1616791773630.png
# score_difference: 0, index: 305, frameName: c23-1616792115757.png
# score_difference: 0, index: 308, frameName: c23-1616793141959.png
# score_difference: 0, index: 309, frameName: c23-1616793484003.png
# score_difference: 0, index: 310, frameName: c23-1616793825924.png
# score_difference: 0, index: 313, frameName: c23-1616794851809.png
# score_difference: 0, index: 314, frameName: c23-1616795193849.png
# score_difference: 0, index: 315, frameName: c23-1616795535932.png
# score_difference: 0, index: 316, frameName: c23-1616795878054.png
# score_difference: 0, index: 317, frameName: c23-1616796220131.png
# score_difference: 0, index: 318, frameName: c23-1616796561976.png
# score_difference: 0, index: 319, frameName: c23-1616796903938.png
# score_difference: 0, index: 320, frameName: c23-1616797245979.png
# score_difference: 0, index: 321, frameName: c23-1616797588141.png
# score_difference: 0, index: 322, frameName: c23-1616797930583.png
# score_difference: 0, index: 323, frameName: c23-1616798272625.png
# score_difference: 0, index: 324, frameName: c23-1616798614663.png
# score_difference: 0, index: 325, frameName: c23-1616798956628.png
# score_difference: 0, index: 326, frameName: c23-1616799298911.png
# score_difference: 0, index: 327, frameName: c23-1616799641030.png
# score_difference: 0, index: 328, frameName: c23-1616799982950.png
# score_difference: 0, index: 329, frameName: c23-1616800324912.png
# score_difference: 0, index: 332, frameName: c23-1616801351157.png
# score_difference: 0, index: 333, frameName: c23-1616801693119.png
# score_difference: 0, index: 334, frameName: c23-1616802035000.png
# score_difference: 0, index: 336, frameName: c23-1616802719081.png
# score_difference: 0, index: 337, frameName: c23-1616803061085.png
# score_difference: 0, index: 340, frameName: c23-1616804087131.png
# score_difference: 0, index: 341, frameName: c23-1616804429172.png
# score_difference: 0, index: 342, frameName: c23-1616804771214.png
# score_difference: 0, index: 343, frameName: c23-1616805113177.png
# score_difference: 0, index: 344, frameName: c23-1616805455339.png
# score_difference: 0, index: 345, frameName: c23-1616805797415.png
# score_difference: 0, index: 346, frameName: c23-1616806139538.png
# score_difference: 0, index: 347, frameName: c23-1616806481550.png
# score_difference: 0, index: 348, frameName: c23-1616806823705.png
# score_difference: 0, index: 349, frameName: c23-1616807165627.png
# score_difference: 0, index: 350, frameName: c23-1616807507626.png
# score_difference: 0, index: 351, frameName: c23-1616807849826.png
# score_difference: 0, index: 352, frameName: c23-1616808191946.png
# score_difference: 0, index: 353, frameName: c23-1616808534030.png
# score_difference: 0, index: 354, frameName: c23-1616808876270.png
# score_difference: 0, index: 355, frameName: c23-1616809218514.png
# score_difference: 0, index: 356, frameName: c23-1616809560594.png
# score_difference: 0, index: 357, frameName: c23-1616809902599.png
# score_difference: 0, index: 358, frameName: c23-1616810244560.png
# score_difference: 0, index: 359, frameName: c23-1616810586997.png
# score_difference: 0, index: 360, frameName: c23-1616810929079.png
# score_difference: 0, index: 361, frameName: c23-1616811271324.png
# score_difference: 0, index: 362, frameName: c23-1616811613406.png
# score_difference: 0, index: 366, frameName: c23-1616812981329.png
# score_difference: 0, index: 367, frameName: c23-1616813323212.png
# score_difference: 0, index: 368, frameName: c23-1616813665096.png
# score_difference: 0, index: 369, frameName: c23-1616814007092.png
# score_difference: 0, index: 371, frameName: c23-1616814691062.png
# score_difference: 0, index: 372, frameName: c23-1616815033103.png
# score_difference: 0, index: 373, frameName: c23-1616815375140.png
# score_difference: 0, index: 374, frameName: c23-1616815717222.png
# score_difference: 0, index: 375, frameName: c23-1616816059387.png
# score_difference: 0, index: 376, frameName: c23-1616816401343.png
# score_difference: 0, index: 377, frameName: c23-1616816743431.png
# score_difference: 0, index: 378, frameName: c23-1616817085591.png
# score_difference: 0, index: 379, frameName: c23-1616817427671.png
# --------------------------- REMOVING SIMILAR IMAGES ------------------------------
# Removing frame: c23-1616696584520.png at index: 26
# Removing frame: c23-1616698981729.png at index: 33
# Removing frame: c23-1616699324009.png at index: 34
# Removing frame: c23-1616699666493.png at index: 35
# Removing frame: c23-1616700009093.png at index: 36
# Removing frame: c23-1616700351574.png at index: 37
# Removing frame: c23-1616700693937.png at index: 38
# Removing frame: c23-1616701036262.png at index: 39
# Removing frame: c23-1616702063501.png at index: 42
# Removing frame: c23-1616702405906.png at index: 43
# Removing frame: c23-1616702748470.png at index: 44
# Removing frame: c23-1616703091109.png at index: 45
# Removing frame: c23-1616703433669.png at index: 46
# Removing frame: c23-1616704460947.png at index: 49
# Removing frame: c23-1616704802950.png at index: 50
# Removing frame: c23-1616705145110.png at index: 51
# Removing frame: c23-1616706171160.png at index: 54
# Removing frame: c23-1616706513398.png at index: 55
# Removing frame: c23-1616706855323.png at index: 56
# Removing frame: c23-1616707197447.png at index: 57
# Removing frame: c23-1616707539404.png at index: 58
# Removing frame: c23-1616708565248.png at index: 61
# Removing frame: c23-1616708907288.png at index: 62
# Removing frame: c23-1616709249289.png at index: 63
# Removing frame: c23-1616709591253.png at index: 64
# Removing frame: c23-1616709933374.png at index: 65
# Removing frame: c23-1616710275420.png at index: 66
# Removing frame: c23-1616710617419.png at index: 67
# Removing frame: c23-1616711644423.png at index: 70
# Removing frame: c23-1616713013068.png at index: 74
# Removing frame: c23-1616713354869.png at index: 75
# Removing frame: c23-1616713696872.png at index: 76
# Removing frame: c23-1616714038835.png at index: 77
# Removing frame: c23-1616714380793.png at index: 78
# Removing frame: c23-1616715406478.png at index: 81
# Removing frame: c23-1616715748441.png at index: 82
# Removing frame: c23-1616716090208.png at index: 83
# Removing frame: c23-1616716432163.png at index: 84
# Removing frame: c23-1616716774165.png at index: 85
# Removing frame: c23-1616717799969.png at index: 88
# Removing frame: c23-1616718142215.png at index: 89
# Removing frame: c23-1616718484220.png at index: 90
# Removing frame: c23-1616719168338.png at index: 92
# Removing frame: c23-1616719852540.png at index: 94
# Removing frame: c23-1616720194661.png at index: 95
# Removing frame: c23-1616720536782.png at index: 96
# Removing frame: c23-1616720878862.png at index: 97
# Removing frame: c23-1616721220750.png at index: 98
# Removing frame: c23-1616721562630.png at index: 99
# Removing frame: c23-1616721904590.png at index: 100
# Removing frame: c23-1616722246353.png at index: 101
# Removing frame: c23-1616722588271.png at index: 102
# Removing frame: c23-1616722930192.png at index: 103
# Removing frame: c23-1616723272395.png at index: 104
# Removing frame: c23-1616723614358.png at index: 105
# Removing frame: c23-1616723956442.png at index: 106
# Removing frame: c23-1616724298401.png at index: 107
# Removing frame: c23-1616724640167.png at index: 108
# Removing frame: c23-1616724982163.png at index: 109
# Removing frame: c23-1616726350617.png at index: 113
# Removing frame: c23-1616726692892.png at index: 114
# Removing frame: c23-1616727034897.png at index: 115
# Removing frame: c23-1616727376939.png at index: 116
# Removing frame: c23-1616727718940.png at index: 117
# Removing frame: c23-1616728060897.png at index: 118
# Removing frame: c23-1616729086908.png at index: 121
# Removing frame: c23-1616729428783.png at index: 122
# Removing frame: c23-1616729770785.png at index: 123
# Removing frame: c23-1616730796952.png at index: 126
# Removing frame: c23-1616732164959.png at index: 130
# Removing frame: c23-1616737298425.png at index: 145
# Removing frame: c23-1616740382406.png at index: 154
# Removing frame: c23-1616783557196.png at index: 280
# Removing frame: c23-1616783899443.png at index: 281
# Removing frame: c23-1616784241640.png at index: 282
# Removing frame: c23-1616784583888.png at index: 283
# Removing frame: c23-1616785611207.png at index: 286
# Removing frame: c23-1616785953569.png at index: 287
# Removing frame: c23-1616786295929.png at index: 288
# Removing frame: c23-1616786638297.png at index: 289
# Removing frame: c23-1616786980657.png at index: 290
# Removing frame: c23-1616788350506.png at index: 294
# Removing frame: c23-1616788692826.png at index: 295
# Removing frame: c23-1616789377672.png at index: 297
# Removing frame: c23-1616789720272.png at index: 298
# Removing frame: c23-1616790062790.png at index: 299
# Removing frame: c23-1616791089592.png at index: 302
# Removing frame: c23-1616791431629.png at index: 303
# Removing frame: c23-1616791773630.png at index: 304
# Removing frame: c23-1616792115757.png at index: 305
# Removing frame: c23-1616793141959.png at index: 308
# Removing frame: c23-1616793484003.png at index: 309
# Removing frame: c23-1616793825924.png at index: 310
# Removing frame: c23-1616794851809.png at index: 313
# Removing frame: c23-1616795193849.png at index: 314
# Removing frame: c23-1616795535932.png at index: 315
# Removing frame: c23-1616795878054.png at index: 316
# Removing frame: c23-1616796220131.png at index: 317
# Removing frame: c23-1616796561976.png at index: 318
# Removing frame: c23-1616796903938.png at index: 319
# Removing frame: c23-1616797245979.png at index: 320
# Removing frame: c23-1616797588141.png at index: 321
# Removing frame: c23-1616797930583.png at index: 322
# Removing frame: c23-1616798272625.png at index: 323
# Removing frame: c23-1616798614663.png at index: 324
# Removing frame: c23-1616798956628.png at index: 325
# Removing frame: c23-1616799298911.png at index: 326
# Removing frame: c23-1616799641030.png at index: 327
# Removing frame: c23-1616799982950.png at index: 328
# Removing frame: c23-1616800324912.png at index: 329
# Removing frame: c23-1616801351157.png at index: 332
# Removing frame: c23-1616801693119.png at index: 333
# Removing frame: c23-1616802035000.png at index: 334
# Removing frame: c23-1616802719081.png at index: 336
# Removing frame: c23-1616803061085.png at index: 337
# Removing frame: c23-1616804087131.png at index: 340
# Removing frame: c23-1616804429172.png at index: 341
# Removing frame: c23-1616804771214.png at index: 342
# Removing frame: c23-1616805113177.png at index: 343
# Removing frame: c23-1616805455339.png at index: 344
# Removing frame: c23-1616805797415.png at index: 345
# Removing frame: c23-1616806139538.png at index: 346
# Removing frame: c23-1616806481550.png at index: 347
# Removing frame: c23-1616806823705.png at index: 348
# Removing frame: c23-1616807165627.png at index: 349
# Removing frame: c23-1616807507626.png at index: 350
# Removing frame: c23-1616807849826.png at index: 351
# Removing frame: c23-1616808191946.png at index: 352
# Removing frame: c23-1616808534030.png at index: 353
# Removing frame: c23-1616808876270.png at index: 354
# Removing frame: c23-1616809218514.png at index: 355
# Removing frame: c23-1616809560594.png at index: 356
# Removing frame: c23-1616809902599.png at index: 357
# Removing frame: c23-1616810244560.png at index: 358
# Removing frame: c23-1616810586997.png at index: 359
# Removing frame: c23-1616810929079.png at index: 360
# Removing frame: c23-1616811271324.png at index: 361
# Removing frame: c23-1616811613406.png at index: 362
# Removing frame: c23-1616812981329.png at index: 366
# Removing frame: c23-1616813323212.png at index: 367
# Removing frame: c23-1616813665096.png at index: 368
# Removing frame: c23-1616814007092.png at index: 369
# Removing frame: c23-1616814691062.png at index: 371
# Removing frame: c23-1616815033103.png at index: 372
# Removing frame: c23-1616815375140.png at index: 373
# Removing frame: c23-1616815717222.png at index: 374
# Removing frame: c23-1616816059387.png at index: 375
# Removing frame: c23-1616816401343.png at index: 376
# Removing frame: c23-1616816743431.png at index: 377
# Removing frame: c23-1616817085591.png at index: 378
# Removing frame: c23-1616817427671.png at index: 379
# --------------------------- TOTAL SIMILAR IMAGES FOUND ----------------------------
# Total removed similar images were: 151

# %% [markdown]
# ## Additional required information

# %% [markdown]
# ##### Q:1 What parameters you decided to use for the provided example dataset

# %% [markdown]
# ###### Ans: I have used only one function "compare_frames_change_detection" to compute similarity score of frame pairs with all required parameters.

# %% [markdown]
# ##### Q:2 How you found those values?

# %% [markdown]
# ###### Ans: prev_frame and next_frame were taken based on their indexes from the given dataset, whereas the final parameter "min_contour_area" was tweaked based on grabed contour values. Nevertheless there were more than 1 minimum values but I decided to go with 50 which worked better in finding similar images.

# %% [markdown]
# ##### Q:3  What amount of duplicates script found with these parameters?

# %% [markdown]
# ###### Ans: I was able to find 151 duplicate frames with score difference of ZERO (0).

# %% [markdown]
# ##### Q:4  What you would suggest improving to make data collection of unique cases better ?

# %% [markdown]
# ###### Ans: In my opinion, it would be better to deploy online solutions to handle duplication of data. For instance, deploy a already trained model or other programs based on the case studies and data requirement to handle redundacny in the data online, which will be helpful and time saving in future.

# %% [markdown]
# ##### Q:5 Any other comments about imaging_interview.py or your solution?

# %% [markdown]
# ###### Ans: I was bit confused about the first two functions in the script that I skipped while implementing my solution. I think the most important function is "compare_frames_change_detection" to detect difference in frames where I added just two lines of extra code to transform the frames from RGB to GrayScale. So, after doing this I thought the other two functions are not that much important as the one I used to remove similar images.
# ###### Last but not least, it would be a great help if the given script has some comments about the functions.
